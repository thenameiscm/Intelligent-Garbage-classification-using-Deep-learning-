# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Extract The Zip Folder

# %%
# !unzip "/content/drive/MyDrive/ds.zip" -d "/content/drive/MyDrive/unzipdataset"
# Out:
# Archive:  /content/drive/MyDrive/ds.zip
# replace /content/drive/MyDrive/unzipdataset/ds/test/cardboard/cardboard108.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# Import Image Data Generator Library

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Setting parameter for image augmentation to the training data

# %%
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.1,zoom_range=0.1,horizontal_flip=True)

# %% [markdown]
# Image data augmentation to the testing data

# %%
val_datagen=ImageDataGenerator(rescale=1./255)

# %% [markdown]
# Loading our data and performing data augmentation

# %%
train_transform=train_datagen.flow_from_directory("/content/drive/MyDrive/unzipdataset/ds/train",target_size=(128,128),batch_size=64,class_mode="categorical")
# Out:
# Found 2527 images belonging to 6 classes.

# %%
test_transform=val_datagen.flow_from_directory("/content/drive/MyDrive/unzipdataset/ds/test",target_size=(128,128),batch_size=64,class_mode="categorical")
# Out:
# Found 526 images belonging to 6 classes.

# %% [markdown]
# Importing Libraries

# %%
#Import Sequential Model
from tensorflow.keras.models import Sequential
#Import Dense Layer
from tensorflow.keras.layers import Dense
#Import Convolution2D Layer
from tensorflow.keras.layers import Convolution2D
#import MaxPooling2d Layer
from tensorflow.keras.layers import MaxPooling2D
#Adding Flatten Layer
from tensorflow .keras. layers import Flatten
from tensorflow .keras .optimizers import Adam

# %% [markdown]
# Intializing The Model

# %%
model=Sequential()

# %% [markdown]
# First Convolution Layer and pooling

# %%
model.add(Convolution2D(32,(3,3),input_shape=(128,128,3),activation="relu"))
model.add(MaxPooling2D(2,2))

# %% [markdown]
# Second Convolution Layer and pooling

# %%
model.add(Convolution2D(64,(3,3),padding="same",activation="relu"))

# %% [markdown]
# input shape is going to be pooled feature maps for the previous convolution

# %%
model.add(MaxPooling2D(2,2))

# %% [markdown]
# Third Convolution layer and pooling

# %%
model.add(Convolution2D(32,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))

# %% [markdown]
# Fourth Convolution layer and pooling

# %%
model.add(Convolution2D(32,(3,3),padding="same",activation='relu'))

# %% [markdown]
# input shape is going to be pooled feature maps for the previous convolution

# %%
model.add(Convolution2D(32,(3,3),padding="same",activation='relu'))

# %% [markdown]
# Flattening The Layers

# %%
model.add(Flatten())

# %% [markdown]
# Adding Fully Connected Layers

# %%
#Adding First Hidden Layer
model.add(Dense(kernel_initializer="uniform",activation="relu",units=150))
#Adding Second Hidden Layer
model.add(Dense(kernel_initializer="uniform",activation="relu",units=68))
model.add(Dense(kernel_initializer="uniform",activation="softmax",units=6))

# %% [markdown]
# Summary Of The Model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 63, 63, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 29, 29, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        9248
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 32)        9248
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 150)               940950
#
#  dense_1 (Dense)             (None, 68)                10268
#
#  dense_2 (Dense)             (None, 6)                 414
#
# =================================================================
# Total params: 1,007,984
# Trainable params: 1,007,984
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compiling The CNN Model

# %%
model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["acc"])

# %% [markdown]
# Fit The Model

# %%
result=model.fit(train_transform,steps_per_epoch=40,validation_steps=9,epochs=30,validation_data=test_transform)
# Out:
# Epoch 1/30
# 40/40 [==============================] - 796s 20s/step - loss: 1.7294 - acc: 0.2311 - val_loss: 1.7193 - val_acc: 0.2205
# Epoch 2/30
# 40/40 [==============================] - 94s 2s/step - loss: 1.6286 - acc: 0.2924 - val_loss: 1.6552 - val_acc: 0.3194
# Epoch 3/30
# 40/40 [==============================] - 92s 2s/step - loss: 1.5677 - acc: 0.3190 - val_loss: 1.5167 - val_acc: 0.3441
# Epoch 4/30
# 40/40 [==============================] - 98s 2s/step - loss: 1.4874 - acc: 0.3439 - val_loss: 1.5083 - val_acc: 0.3593
# Epoch 5/30
# 40/40 [==============================] - 91s 2s/step - loss: 1.4699 - acc: 0.3558 - val_loss: 1.3800 - val_acc: 0.4240
# Epoch 6/30
# 40/40 [==============================] - 94s 2s/step - loss: 1.3594 - acc: 0.4270 - val_loss: 1.3861 - val_acc: 0.4487
# Epoch 7/30
# 40/40 [==============================] - 88s 2s/step - loss: 1.3017 - acc: 0.4527 - val_loss: 1.2455 - val_acc: 0.5019
# Epoch 8/30
# 40/40 [==============================] - 89s 2s/step - loss: 1.2170 - acc: 0.5049 - val_loss: 1.1748 - val_acc: 0.5608
# Epoch 9/30
# 40/40 [==============================] - 94s 2s/step - loss: 1.1542 - acc: 0.5505 - val_loss: 1.1368 - val_acc: 0.5608
# Epoch 10/30
# 40/40 [==============================] - 89s 2s/step - loss: 1.0906 - acc: 0.5829 - val_loss: 1.0824 - val_acc: 0.5970
# Epoch 11/30
# 40/40 [==============================] - 95s 2s/step - loss: 1.0575 - acc: 0.6063 - val_loss: 1.0929 - val_acc: 0.6084
# Epoch 12/30
# 40/40 [==============================] - 88s 2s/step - loss: 1.0080 - acc: 0.6177 - val_loss: 1.0258 - val_acc: 0.6578
# Epoch 13/30
# 40/40 [==============================] - 89s 2s/step - loss: 0.9328 - acc: 0.6549 - val_loss: 0.9016 - val_acc: 0.6711
# Epoch 14/30
# 40/40 [==============================] - 90s 2s/step - loss: 0.9107 - acc: 0.6609 - val_loss: 0.9083 - val_acc: 0.6635
# Epoch 15/30
# 40/40 [==============================] - 90s 2s/step - loss: 0.8456 - acc: 0.6882 - val_loss: 0.9088 - val_acc: 0.6464
# Epoch 16/30
# 40/40 [==============================] - 90s 2s/step - loss: 0.7980 - acc: 0.7083 - val_loss: 0.8050 - val_acc: 0.6996
# Epoch 17/30
# 40/40 [==============================] - 91s 2s/step - loss: 0.7650 - acc: 0.7186 - val_loss: 0.7073 - val_acc: 0.7471
# Epoch 18/30
# 40/40 [==============================] - 90s 2s/step - loss: 0.7480 - acc: 0.7262 - val_loss: 0.7080 - val_acc: 0.7338
# Epoch 19/30
# 40/40 [==============================] - 89s 2s/step - loss: 0.7604 - acc: 0.7210 - val_loss: 0.7363 - val_acc: 0.7376
# Epoch 20/30
# 40/40 [==============================] - 89s 2s/step - loss: 0.6311 - acc: 0.7634 - val_loss: 0.6790 - val_acc: 0.7376
# Epoch 21/30
# 40/40 [==============================] - 91s 2s/step - loss: 0.5674 - acc: 0.7994 - val_loss: 0.6005 - val_acc: 0.7928
# Epoch 22/30
# 40/40 [==============================] - 90s 2s/step - loss: 0.5676 - acc: 0.7942 - val_loss: 0.5933 - val_acc: 0.7795
# Epoch 23/30
# 40/40 [==============================] - 88s 2s/step - loss: 0.5077 - acc: 0.8227 - val_loss: 0.5686 - val_acc: 0.8042
# Epoch 24/30
# 40/40 [==============================] - 90s 2s/step - loss: 0.4927 - acc: 0.8298 - val_loss: 0.5787 - val_acc: 0.8042
# Epoch 25/30
# 40/40 [==============================] - 88s 2s/step - loss: 0.4579 - acc: 0.8346 - val_loss: 0.5679 - val_acc: 0.7852
# Epoch 26/30
# 40/40 [==============================] - 94s 2s/step - loss: 0.4824 - acc: 0.8251 - val_loss: 0.4606 - val_acc: 0.8346
# Epoch 27/30
# 40/40 [==============================] - 90s 2s/step - loss: 0.3778 - acc: 0.8643 - val_loss: 0.4192 - val_acc: 0.8384
# Epoch 28/30
# 40/40 [==============================] - 94s 2s/step - loss: 0.3849 - acc: 0.8643 - val_loss: 0.3986 - val_acc: 0.8897
# Epoch 29/30
# 40/40 [==============================] - 89s 2s/step - loss: 0.3233 - acc: 0.8825 - val_loss: 0.4248 - val_acc: 0.8669
# Epoch 30/30
# 40/40 [==============================] - 89s 2s/step - loss: 0.2825 - acc: 0.8939 - val_loss: 0.4534 - val_acc: 0.8631

# %% [markdown]
# Save The Model

# %%
model.save("Garbage3.h5")

# %% [markdown]
# Test The Data

# %%
#import numpy
import numpy as np
#import the load model to load your saved model
from tensorflow.keras.models import load_model
#import image preprocessing
from tensorflow.keras.preprocessing import image
#loading your saved model file
model=load_model("Garbage3.h5")

# %% [markdown]
# Taking An Image

# %%
img= image.load_img("/content/drive/MyDrive/unzipdataset/ds/test/cardboard/cardboard153.jpg",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)

# %%
a=np.argmax(model.predict(x), axis=1)
# Out:
# 1/1 [==============================] - 0s 41ms/step

# %%
index=['0','1','2','3','4','5']
result=str(index[a[0]])
result
# Out:
# '0'

# %%
train_transform.class_indices
# Out:
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'paper': 3, 'plastic': 4, 'trash': 5}

# %% [markdown]
# By using the model we are predicting the output by using image

# %%
index1=['cardboard','glass','metal','paper','palstic','trash']
result1=str(index1[a[0]])
result1
# Out:
# 'cardboard'
